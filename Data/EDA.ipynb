# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../Data/countyVLivEdu.csv')
data
# Out:
#        Unnamed: 0  case_id state_x  isMetro            areaname   county  \
# 0               0        1      AL     True  Montgomery, AL MSA  Autauga
# 1               1        1      AL     True  Montgomery, AL MSA  Autauga
# 2               2        1      AL     True  Montgomery, AL MSA  Autauga
# 3               3        1      AL     True  Montgomery, AL MSA  Autauga
# 4               4        1      AL     True  Montgomery, AL MSA  Autauga
# ...           ...      ...     ...      ...                 ...      ...
# 22185       22185     3171      WY    False   Weston County, WY   Weston
# 22186       22186     3171      WY    False   Weston County, WY   Weston
# 22187       22187     3171      WY    False   Weston County, WY   Weston
# 22188       22188     3171      WY    False   Weston County, WY   Weston
# 22189       22189     3171      WY    False   Weston County, WY   Weston
#
#       family_member_count  housing_cost    food_cost  transportation_cost  \
# 0                    1p0c    8505.72876   3454.91712          10829.16876
# 1                    1p1c   12067.50240   5091.70788          11588.19288
# 2                    1p2c   12067.50240   7460.20308          12361.77720
# 3                    1p3c   15257.15040   9952.23924          13452.18600
# 4                    1p4c   15257.15040  12182.21400          13744.59840
# ...                   ...           ...          ...                  ...
# 22185                2p0c    8316.00000   6010.65672          14790.36240
# 22186                2p1c   10956.00000   7480.86696          15611.58600
# 22187                2p2c   10956.00000   9474.35748          16163.90280
# 22188                2p3c   13632.00000  11567.46972          17118.38400
# 22189                2p4c   13632.00000  14155.81080          17184.34920
#
#        ...        Col  state_y  county_name  totalvotes  DEMOCRAT  GREEN  \
# 0      ...  28.131469  ALABAMA      Autauga       27770  0.270184    0.0
# 1      ...  28.131469  ALABAMA      Autauga       27770  0.270184    0.0
# 2      ...  28.131469  ALABAMA      Autauga       27770  0.270184    0.0
# 3      ...  28.131469  ALABAMA      Autauga       27770  0.270184    0.0
# 4      ...  28.131469  ALABAMA      Autauga       27770  0.270184    0.0
# ...    ...        ...      ...          ...         ...       ...    ...
# 22185  ...  18.397383  WYOMING       Weston        3560  0.101124    0.0
# 22186  ...  18.397383  WYOMING       Weston        3560  0.101124    0.0
# 22187  ...  18.397383  WYOMING       Weston        3560  0.101124    0.0
# 22188  ...  18.397383  WYOMING       Weston        3560  0.101124    0.0
# 22189  ...  18.397383  WYOMING       Weston        3560  0.101124    0.0
#
#        LIBERTARIAN     OTHER  REPUBLICAN  Abv
# 0         0.000000  0.015448    0.714368   AL
# 1         0.000000  0.015448    0.714368   AL
# 2         0.000000  0.015448    0.714368   AL
# 3         0.000000  0.015448    0.714368   AL
# 4         0.000000  0.015448    0.714368   AL
# ...            ...       ...         ...  ...
# 22185     0.012921  0.013202    0.872753   WY
# 22186     0.012921  0.013202    0.872753   WY
# 22187     0.012921  0.013202    0.872753   WY
# 22188     0.012921  0.013202    0.872753   WY
# 22189     0.012921  0.013202    0.872753   WY
#
# [22190 rows x 29 columns]

# %%
#how to make variable for pluraility of edu/voter info

# %%
#sns.pairplot(data=data, hue='family_member_count')
#plt.savefig("seaborn_plot.jpg", dpi=300)

# %%
def plurality(row):
    # Calculate percentage for each column
    percentages = row / row.sum() * 100
    # Get the party with the highest percentage
    return percentages.idxmax()

# Create a new column containing the most voted party for each row
data['most_voted_party'] = data[['REPUBLICAN', 'DEMOCRAT', 'LIBERTARIAN', 'GREEN', 'OTHER']].apply(plurality, axis=1)
data['common_education'] = data[['noHS', 'HS',	'someCol',	'Col']].apply(plurality, axis=1)

# Display the updated DataFrame
data[['noHS', 'HS',	'someCol',	'Col', 'common_education']]
# Out:
#             noHS         HS    someCol        Col common_education
# 0      10.415510  32.758621  28.694401  28.131469               HS
# 1      10.415510  32.758621  28.694401  28.131469               HS
# 2      10.415510  32.758621  28.694401  28.131469               HS
# 3      10.415510  32.758621  28.694401  28.131469               HS
# 4      10.415510  32.758621  28.694401  28.131469               HS
# ...          ...        ...        ...        ...              ...
# 22185   7.113655  37.326247  37.162715  18.397383               HS
# 22186   7.113655  37.326247  37.162715  18.397383               HS
# 22187   7.113655  37.326247  37.162715  18.397383               HS
# 22188   7.113655  37.326247  37.162715  18.397383               HS
# 22189   7.113655  37.326247  37.162715  18.397383               HS
#
# [22190 rows x 5 columns]

# %%
#data[data['common_education'] == 'noHS']
data['most_voted_party'].value_counts()
data['common_education'].value_counts()
data
# Out:
#        Unnamed: 0  case_id state_x  isMetro            areaname   county  \
# 0               0        1      AL     True  Montgomery, AL MSA  Autauga
# 1               1        1      AL     True  Montgomery, AL MSA  Autauga
# 2               2        1      AL     True  Montgomery, AL MSA  Autauga
# 3               3        1      AL     True  Montgomery, AL MSA  Autauga
# 4               4        1      AL     True  Montgomery, AL MSA  Autauga
# ...           ...      ...     ...      ...                 ...      ...
# 22185       22185     3171      WY    False   Weston County, WY   Weston
# 22186       22186     3171      WY    False   Weston County, WY   Weston
# 22187       22187     3171      WY    False   Weston County, WY   Weston
# 22188       22188     3171      WY    False   Weston County, WY   Weston
# 22189       22189     3171      WY    False   Weston County, WY   Weston
#
#       family_member_count  housing_cost    food_cost  transportation_cost  \
# 0                    1p0c    8505.72876   3454.91712          10829.16876
# 1                    1p1c   12067.50240   5091.70788          11588.19288
# 2                    1p2c   12067.50240   7460.20308          12361.77720
# 3                    1p3c   15257.15040   9952.23924          13452.18600
# 4                    1p4c   15257.15040  12182.21400          13744.59840
# ...                   ...           ...          ...                  ...
# 22185                2p0c    8316.00000   6010.65672          14790.36240
# 22186                2p1c   10956.00000   7480.86696          15611.58600
# 22187                2p2c   10956.00000   9474.35748          16163.90280
# 22188                2p3c   13632.00000  11567.46972          17118.38400
# 22189                2p4c   13632.00000  14155.81080          17184.34920
#
#        ...  county_name  totalvotes  DEMOCRAT  GREEN  LIBERTARIAN     OTHER  \
# 0      ...      Autauga       27770  0.270184    0.0     0.000000  0.015448
# 1      ...      Autauga       27770  0.270184    0.0     0.000000  0.015448
# 2      ...      Autauga       27770  0.270184    0.0     0.000000  0.015448
# 3      ...      Autauga       27770  0.270184    0.0     0.000000  0.015448
# 4      ...      Autauga       27770  0.270184    0.0     0.000000  0.015448
# ...    ...          ...         ...       ...    ...          ...       ...
# 22185  ...       Weston        3560  0.101124    0.0     0.012921  0.013202
# 22186  ...       Weston        3560  0.101124    0.0     0.012921  0.013202
# 22187  ...       Weston        3560  0.101124    0.0     0.012921  0.013202
# 22188  ...       Weston        3560  0.101124    0.0     0.012921  0.013202
# 22189  ...       Weston        3560  0.101124    0.0     0.012921  0.013202
#
#        REPUBLICAN  Abv  most_voted_party  common_education
# 0        0.714368   AL        REPUBLICAN                HS
# 1        0.714368   AL        REPUBLICAN                HS
# 2        0.714368   AL        REPUBLICAN                HS
# 3        0.714368   AL        REPUBLICAN                HS
# 4        0.714368   AL        REPUBLICAN                HS
# ...           ...  ...               ...               ...
# 22185    0.872753   WY        REPUBLICAN                HS
# 22186    0.872753   WY        REPUBLICAN                HS
# 22187    0.872753   WY        REPUBLICAN                HS
# 22188    0.872753   WY        REPUBLICAN                HS
# 22189    0.872753   WY        REPUBLICAN                HS
#
# [22190 rows x 31 columns]

# %%
sns.scatterplot(x=data.groupby(['county', 'state_x'])['total_cost'].mean(), 
                y = data.groupby(['county', 'state_x'])['median_family_income'].mean(),
                hue=data.groupby(['county', 'state_x'])['common_education'].first())
# Out:
# <Axes: xlabel='total_cost', ylabel='median_family_income'>

# %%
sns.scatterplot(x=data.groupby(['county', 'state_x'])['total_cost'].mean(), 
                y = data.groupby(['county', 'state_x'])['median_family_income'].mean(),
                hue=data.groupby(['county', 'state_x'])['most_voted_party'].first())
# Out:
# <Axes: xlabel='total_cost', ylabel='median_family_income'>

# %%
sns.scatterplot(x=data['total_cost'], 
                y = data['median_family_income'],
                hue=data['family_member_count'])
# Out:
# <Axes: xlabel='total_cost', ylabel='median_family_income'>

# %%
sns.scatterplot(x=data['housing_cost'], 
                y = data['median_family_income'],
                hue=data['family_member_count'])
# Out:
# <Axes: xlabel='housing_cost', ylabel='median_family_income'>
